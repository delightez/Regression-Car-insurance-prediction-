# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# In this notebook we will expand our simple linear regression model that we built to predict car prices in the last chapter to include several independent variables in order to produce better predictions.

# %% [markdown]
# ### Package and Data Loading
#
# As before, we will import the required packages and our car price data set.

# %%
import pandas as pd
import matplotlib.pyplot as plot
import statsmodels.api as stats
import numpy as np

# %%
carprice_df = pd.read_csv('CarPrice_Assignment.csv')

# %% [markdown]
# ### Assessing the Data

# %%
carprice_df.shape
# Out:
# (205, 26)

# %%
carprice_df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# We can see all the columns and what data type they are using [df.info()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html) and how many unique values there are for the categorical types using [df.nunique()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.nunique.html).

# %%
carprice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %% [markdown]
# Here we are checking the number of unique values in specifically the categorical variables using [df.select_dtypes()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html)

# %%
carprice_df.select_dtypes(include='object').nunique()
# Out:
# CarName           147
# fueltype            2
# aspiration          2
# doornumber          2
# carbody             5
# drivewheel          3
# enginelocation      2
# enginetype          7
# cylindernumber      7
# fuelsystem          8
# dtype: int64

# %% [markdown]
# As we can see, the data contains a mixture of numeric types and categorical (object) types. We will remove the car_ID field from the data as this is only an identifier. For the purposes of this lesson we will also remove CarName from the data as it contains a large number of unique values (How could we extract more useful information from this variable?).

# %%
carprice_df = carprice_df.drop(columns=['car_ID', 'CarName'])

# %%
carprice_df.select_dtypes(exclude='object').corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_935ed_row0_col0, #T_935ed_row1_col1, #T_935ed_row2_col2, #T_935ed_row3_col3, #T_935ed_row4_col4, #T_935ed_row5_col5, #T_935ed_row6_col6, #T_935ed_row7_col7, #T_935ed_row8_col8, #T_935ed_row9_col9, #T_935ed_row10_col10, #T_935ed_row11_col11, #T_935ed_row12_col12, #T_935ed_row13_col13, #T_935ed_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_935ed_row0_col1, #T_935ed_row7_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_935ed_row0_col2, #T_935ed_row5_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_935ed_row0_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_935ed_row0_col4, #T_935ed_row4_col0, #T_935ed_row5_col13, #T_935ed_row9_col11, #T_935ed_row10_col12, #T_935ed_row11_col8, #T_935ed_row11_col9, #T_935ed_row12_col7, #T_935ed_row12_col10, #T_935ed_row13_col1, #T_935ed_row13_col2, #T_935ed_row13_col3, #T_935ed_row13_col5, #T_935ed_row13_col6, #T_935ed_row13_col7, #T_935ed_row13_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_935ed_row0_col5, #T_935ed_row12_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_935ed_row0_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_935ed_row0_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_935ed_row0_col8, #T_935ed_row14_col13 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_935ed_row0_col9 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_935ed_row0_col10, #T_935ed_row4_col14 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_935ed_row0_col11 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_935ed_row0_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_935ed_row0_col13, #T_935ed_row7_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_935ed_row0_col14 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_935ed_row1_col0, #T_935ed_row12_col14 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_935ed_row1_col2, #T_935ed_row3_col5, #T_935ed_row5_col2, #T_935ed_row6_col14 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_935ed_row1_col3, #T_935ed_row1_col5 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_935ed_row1_col4, #T_935ed_row4_col1, #T_935ed_row10_col7 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_935ed_row1_col6 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_935ed_row1_col7 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_935ed_row1_col8 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_935ed_row1_col9, #T_935ed_row4_col7 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_935ed_row1_col10 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_935ed_row1_col11, #T_935ed_row2_col13 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_935ed_row1_col12, #T_935ed_row2_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_935ed_row1_col13, #T_935ed_row11_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_935ed_row1_col14, #T_935ed_row2_col7, #T_935ed_row2_col10, #T_935ed_row7_col6 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_935ed_row2_col0, #T_935ed_row5_col11, #T_935ed_row7_col12, #T_935ed_row11_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_935ed_row2_col1, #T_935ed_row5_col3 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_935ed_row2_col3, #T_935ed_row5_col14 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_935ed_row2_col4, #T_935ed_row7_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_935ed_row2_col5 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_935ed_row2_col6 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_935ed_row2_col9, #T_935ed_row11_col13 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_935ed_row2_col11 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_935ed_row2_col12 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_935ed_row2_col14, #T_935ed_row6_col2, #T_935ed_row14_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_935ed_row3_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_935ed_row3_col1 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_935ed_row3_col2, #T_935ed_row14_col5 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_935ed_row3_col4 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_935ed_row3_col6, #T_935ed_row6_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_935ed_row3_col7, #T_935ed_row6_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_935ed_row3_col8, #T_935ed_row9_col0, #T_935ed_row9_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_935ed_row3_col9, #T_935ed_row14_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_935ed_row3_col10 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_935ed_row3_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_935ed_row3_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_935ed_row3_col13, #T_935ed_row6_col13 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_935ed_row3_col14, #T_935ed_row14_col3 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_935ed_row4_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_935ed_row4_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_935ed_row4_col5 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_935ed_row4_col6 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_935ed_row4_col8, #T_935ed_row10_col13, #T_935ed_row12_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_935ed_row4_col9, #T_935ed_row13_col9 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_935ed_row4_col10, #T_935ed_row4_col13 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_935ed_row4_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_935ed_row4_col12 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_935ed_row5_col1 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_935ed_row5_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_935ed_row5_col6 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_935ed_row5_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_935ed_row5_col8 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_935ed_row5_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_935ed_row5_col10, #T_935ed_row10_col5 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_935ed_row5_col12, #T_935ed_row12_col8 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_935ed_row6_col0, #T_935ed_row13_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_935ed_row6_col4, #T_935ed_row10_col0, #T_935ed_row10_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_935ed_row6_col5 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_935ed_row6_col7, #T_935ed_row7_col3, #T_935ed_row7_col14, #T_935ed_row10_col2 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_935ed_row6_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_935ed_row6_col9 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_935ed_row6_col10, #T_935ed_row14_col10 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_935ed_row6_col11 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_935ed_row6_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_935ed_row7_col0, #T_935ed_row13_col11 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_935ed_row7_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_935ed_row7_col5 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_935ed_row7_col9 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_935ed_row7_col10 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_935ed_row7_col11 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_935ed_row7_col13 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_935ed_row8_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_935ed_row8_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_935ed_row8_col2, #T_935ed_row8_col10 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_935ed_row8_col3, #T_935ed_row9_col1, #T_935ed_row9_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_935ed_row8_col4 {
#   background-color: #a3c2fe;
#   color: #

# %% [markdown]
# We can see that highwaympg and citympg are highly correlated with a correlation coefficient of 0.97. Removing highwympg will get rid of this correlation and help reduce the complexity of our model. We also choose to remove carlength and carwidth to remove some more high correlations.

# %%
carprice_df = carprice_df.drop(columns=['carlength', 'carwidth', 'highwaympg'])

# %% [markdown]
# #### One Hot Encoding
#
# We can also use the categorical data by one-hot-encoding the it. This is where we make each category in a categorical variable its own independent variable which has a binary 1/0 value.

# %%
dummy = pd.get_dummies(carprice_df.select_dtypes(include='object'), drop_first=True)

# %%
carprice_df = pd.concat([carprice_df.select_dtypes(exclude='object'), dummy], axis=1)

# %% [markdown]
# We can repeat the above process where we remove highly correlated variables, now including the one hot encoded features.

# %%
carprice_df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_badd6_row0_col0, #T_badd6_row1_col1, #T_badd6_row2_col2, #T_badd6_row3_col3, #T_badd6_row4_col4, #T_badd6_row5_col5, #T_badd6_row6_col6, #T_badd6_row7_col7, #T_badd6_row8_col8, #T_badd6_row9_col9, #T_badd6_row10_col10, #T_badd6_row11_col11, #T_badd6_row12_col12, #T_badd6_row13_col13, #T_badd6_row14_col14, #T_badd6_row15_col15, #T_badd6_row16_col16, #T_badd6_row17_col17, #T_badd6_row18_col18, #T_badd6_row19_col19, #T_badd6_row20_col20, #T_badd6_row21_col21, #T_badd6_row22_col22, #T_badd6_row23_col23, #T_badd6_row24_col24, #T_badd6_row25_col25, #T_badd6_row26_col26, #T_badd6_row27_col27, #T_badd6_row27_col33, #T_badd6_row28_col28, #T_badd6_row29_col29, #T_badd6_row30_col30, #T_badd6_row31_col31, #T_badd6_row32_col32, #T_badd6_row33_col27, #T_badd6_row33_col33, #T_badd6_row34_col34, #T_badd6_row35_col35, #T_badd6_row36_col36, #T_badd6_row37_col37, #T_badd6_row38_col38, #T_badd6_row39_col39, #T_badd6_row40_col40 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_badd6_row0_
col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_badd6_row0_col21, #T_badd6_row0_col35, #T_badd6_row2_col12, #T_badd6_row22_col0, #T_badd6_row22_col34, #T_badd6_row25_col17, #T_badd6_row27_col38, #T_badd6_row32_col34, #T_badd6_row33_col38, #T_badd6_row37_col34, #T_badd6_row38_col0, #T_badd6_row39_col30, #T_badd6_row40_col34 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_badd6_row0_col22, #T_badd6_row3_col37, #T_badd6_row9_col31, #T_badd6_row18_col32, #T_badd6_row22_col31, #T_badd6_row24_col15, #T_badd6_row30_col32, #T_badd6_row32_col31, #T_badd6_row37_col31, #T_badd6_row39_col15, #T_badd6_row40_col31 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_badd6_row0_col23, #T_badd6_row6_col18, #T_badd6_row13_col34, #T_badd6_row16_col23, #T_badd6_row34_col6, #T_badd6_row38_col29 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_badd6_row0_col24, #T_badd6_row5_col22, #T_badd6_row11_col22, #T_badd6_row16_col11, #T_badd6_row27_c

# %%
carprice_df = carprice_df.drop(columns=['compressionratio', 'drivewheel_fwd', 'enginetype_rotor', 'fuelsystem_4bbl', 'fuelsystem_idi'])

# %%
carprice_df.shape
# Out:
# (205, 36)

# %% [markdown]
# ## Scikit-Learn
#
# I did this project using Scikit-Learn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Test/Train Split

# %% [markdown]
# When we have multiple independent variables, we do not need to reshape our X array as it is already a 2D array. We can therefore insert our training independent variables straight into the fitting method.

# %%
Y = carprice_df.price
X = carprice_df.drop(columns=['price'])

# %%
sk_X_train, sk_X_test, sk_Y_train, sk_Y_test = train_test_split(X, Y, test_size=0.3, random_state=99)

# %%
regressor = LinearRegression()  
regressor.fit(sk_X_train, sk_Y_train)
# Out:
# LinearRegression()

# %%
sk_intercept_carprice = regressor.intercept_
sk_engsize_coeffs = regressor.coef_
sk_ssr_carprice = np.sum((sk_Y_train-regressor.predict(sk_X_train))**2)

# %%
pd.Series(sk_engsize_coeffs, index=sk_X_train.columns)
# Out:
# symboling                2.523350e+02
# wheelbase                7.412976e+01
# carheight                8.309020e+01
# curbweight               4.839412e+00
# enginesize               1.715172e+02
# boreratio               -5.949063e+03
# stroke                  -6.214262e+03
# horsepower               2.217799e+01
# peakrpm                  2.154338e+00
# citympg                  4.212092e+01
# fueltype_gas            -1.110769e+03
# aspiration_turbo         2.083399e+03
# doornumber_two          -6.671472e+01
# carbody_hardtop         -2.879089e+03
# carbody_hatchback       -2.613059e+03
# carbody_sedan           -1.980960e+03
# carbody_wagon           -3.223607e+03
# drivewheel_rwd           2.109262e+02
# enginelocation_rear      8.110262e+03
# enginetype_dohcv         1.368412e+03
# enginetype_l             4.717644e+02
# enginetype_ohc           4.039236e+03
# enginetype_ohcf          2.413523e+03
# enginetype_ohcv         -2.760030e+03
# cylindernumber_five     -1.192809e+03
# cylindernumber_four     -1.295218e+03
# cylindernumber_six      -2.770013e+03
# cylindernumber_three     7.452953e+03
# cylindernumber_twelve   -1.818989e-12
# cylindernumber_two       1.050071e+04
# fuelsystem_2bbl         -4.286271e+01
# fuelsystem_mfi          -3.633462e+03
# fuelsystem_mpfi          8.801415e+00
# fuelsystem_spdi         -2.196945e+03
# fuelsystem_spfi          0.000000e+00
# dtype: float64

# %%
print('The intercept value is {:.1f}'.format(sk_intercept_carprice))
print('The sum of square residuals is {:.1f}'.format(sk_ssr_carprice))
# Out:
# The intercept value is -5972.4
# The sum of square residuals is 496875718.4
